# %% [markdown]
# Let's compare the different models we have created. We have 7 models to compare: A naive model, a Bayes classifier, logistic regression, knn, a decision tree, random forest, and gradient boosting.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
sns.set_style("whitegrid")

# %%
Models = np.array(['Baseline', 'Naive Bayes', 'Logistic Regression', 'KNN', 'Decision Tree','Random Forest','Extra Trees','Gradient Boosting'])
Accuracies = np.array([0.5976635514018691, 0.831385837812573, 0.7768170133208694, 0.8615330684739425, 0.8863052114980136, 0.8910960504790839, 0.8650385604113111,0.9107268053283477])
Recalls = np.array([1.000000000, 0.7345338367702585, 0.73772872, 0.8755821689953427, 0.82776648, 0.8091780424048794, 0.7693871623584083 ,0.87307581])
Precisions = np.array([0.59766355, 0.8270111183780249, 0.71609811, 0.8755821689953427, 0.88235294, 0.9101600784057498,0.8800664451827243 ,0.90189019])
F1s = np.array([0.74817198, 0.780000, 0.7267525, 0.8162505814855017, 0.85418852,0.8567035670356704,0.8210134821013482, 0.88724911 ])

# %%
plt.figure(figsize=(12,7))
plt.bar(Models, Accuracies)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("Model", fontsize=12)
plt.ylabel("Accuracy Score", fontsize=12)

plt.show()

# %%
plt.figure(figsize=(14,7), facecolor = ('#fffbf0'))

plt.plot(Models, Accuracies, 'o', label = 'Accuracy Scores' )
plt.plot(Models, Precisions, 'o', label = 'Precision Scores')
plt.plot(Models, Recalls, 'o', label = 'Recall Scores')
plt.plot(Models, F1s, 'o', label = 'F1 Scores')
plt.legend(loc = 'upper center')


plt.plot(Models, Accuracies*0 + np.max(Precisions),'-.', color = 'orange')
plt.plot(Models, Accuracies*0 + np.max(Recalls),'--', color = 'green')
plt.plot(Models, Accuracies*0 + np.max(F1s),'--', color = 'red')
plt.plot(Models, Accuracies*0 + np.max(Accuracies),'--', color = 'blue')
plt.plot([],[],'--', label = 'Maximum Scores', color = 'black')
plt.legend(loc = 'lower center')



plt.xticks(fontsize=10)
plt.yticks([.6 + .05*i for i in range(9)],fontsize=10)

ax = plt.gca()
ax.set_facecolor('#fffbf0')



plt.xlabel("Model", fontsize=12)
plt.ylabel("Score", fontsize=12)

plt.show()

# %% [markdown]
# Based on comparing the most important features across different models (where feature importance was measured), the most important ones were latitude (logistic regression, gradient boosting, decision tree), longitude (logistic regression, gradient boosting, decision tree, random forest, extra trees), and exterior siding (logistic regression, random forest, extra trees).
